# %% [markdown]
# # Kontrast Germe

# %% [markdown]
# ![kontrastgerme2.png](attachment:kontrastgerme2.png)

# %% [markdown]
# Soru 1. S nedir? ![kontrastgermes1.png](attachment:kontrastgermes1.png)

# %% [markdown]
# ![cozum1.png](attachment:cozum1.png)

# %% [markdown]
# Soru 2. S nedir? ![kontrastgermes2.png](attachment:kontrastgermes2.png)

# %% [markdown]
# ![cozum2.png](attachment:cozum2.png)

# %% [markdown]
# Soru 3. S nedir?![kontrastgermes3.png](attachment:kontrastgermes3.png)

# %% [markdown]
# ![cozum3.png](attachment:cozum3.png)
