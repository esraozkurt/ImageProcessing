# %% [markdown]
# # Histogram Denklestirme

# %% [markdown]
# ![histogram1.png](attachment:histogram1.png)

# %% [markdown]
# ![histogram2.png](attachment:histogram2.png)

# %% [markdown]
# ![histogram3.png](attachment:histogram3.png)
